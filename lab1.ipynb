# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# %%
raw_data = pd.read_csv('heart_failure.csv')
print(raw_data.head)
# Out:
# <bound method NDFrame.head of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
scaler = MinMaxScaler()
scaler.fit(raw_data.drop('DEATH_EVENT', axis=1))
scaled_features = scaler.transform(raw_data.drop('DEATH_EVENT', axis=1))
scaled_data = pd.DataFrame(scaled_features, columns = raw_data.drop('DEATH_EVENT', axis=1).columns)
#print(scaled_data)

# %%
features = scaled_data
labels = raw_data['DEATH_EVENT']
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size= 0.2, random_state = 14)
mlnNB = MultinomialNB() 
mlnNB.fit(features_train, labels_train)
predictions = mlnNB.predict(features_test)
print(classification_report(labels_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.85        44
#            1       1.00      0.06      0.12        16
#
#     accuracy                           0.75        60
#    macro avg       0.87      0.53      0.49        60
# weighted avg       0.81      0.75      0.66        60

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
scaler1 = StandardScaler()
scaler1.fit(raw_data.drop('DEATH_EVENT', axis=1))
scaled_features1 = scaler.transform(raw_data.drop('DEATH_EVENT', axis=1))
scaled_data1 = pd.DataFrame(scaled_features1, columns = raw_data.drop('DEATH_EVENT', axis=1).columns)

# %%
x = scaled_data1
y = raw_data['DEATH_EVENT']
x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x, y, test_size = 0.2)
model = KNeighborsClassifier(n_neighbors = 1)
model.fit(x_training_data, y_training_data)
predictions1 = model.predict(x_test_data)
print(classification_report(y_test_data, predictions1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        43
#            1       0.47      0.47      0.47        17
#
#     accuracy                           0.70        60
#    macro avg       0.63      0.63      0.63        60
# weighted avg       0.70      0.70      0.70        60

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
Linregressor = LinearRegression()
Linregressor.fit(X_train, y_train)
Logregressor = LogisticRegression(max_iter=1000)
Logregressor.fit(X_train, y_train)
Lin_pred = Linregressor.predict(X_test)
Log_pred = Logregressor.predict(X_test)
print("LinearRegression")
print('Mean absolute error:', metrics.mean_absolute_error(y_test, Lin_pred))
print('Mean squared error:', metrics.mean_squared_error(y_test, Lin_pred))
print('Root-mean-square deviation:', np.sqrt(metrics.mean_squared_error(y_test, Lin_pred)))
print("LogisticRegression")
print('Mean absolute error:', (metrics.mean_absolute_error(y_test, Log_pred)))
print('Mean squared error:', metrics.mean_squared_error(y_test, Log_pred))
print('Root-mean-square deviation:', np.sqrt(metrics.mean_squared_error(y_test, Log_pred)))
# Out:
# LinearRegression
# Mean absolute error: 0.3306978717548962
# Mean squared error: 0.1549606672629354
# Root-mean-square deviation: 0.3936504379051742
# LogisticRegression
# Mean absolute error: 0.2
# Mean squared error: 0.2
# Root-mean-square deviation: 0.4472135954999579

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,train_size = 0.3, random_state = 1)
svc = SVC(C=1.0, random_state=1, kernel='linear')
svc.fit(x_training_data, y_training_data)
predictions2 = svc.predict(x_test_data)
print(classification_report(y_test_data, predictions2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        43
#            1       0.60      0.71      0.65        17
#
#     accuracy                           0.78        60
#    macro avg       0.74      0.76      0.75        60
# weighted avg       0.80      0.78      0.79        60

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from c45 import C45
from sklearn import tree

# %%
CART = DecisionTreeClassifier()
CART = CART.fit(X_train,y_train)
CART_pred = CART.predict(X_test)
print(classification_report(y_test, CART_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       141
#            1       0.70      0.55      0.62        69
#
#     accuracy                           0.78       210
#    macro avg       0.75      0.72      0.73       210
# weighted avg       0.77      0.78      0.77       210

# %%
plt.figure(figsize = (10, 10))
tree.plot_tree(CART, feature_names = X_train.columns, class_names= ['T', 'CT'], filled = True)
plt.show()

# %%
clf = C45(None)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
c = clf.fit(X_train, y_train)
c45_pred = c.predict(X_test)
print(classification_report(y_test, c45_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85        55
#            1       0.59      0.80      0.68        20
#
#     accuracy                           0.80        75
#    macro avg       0.75      0.80      0.77        75
# weighted avg       0.83      0.80      0.81        75

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
X = iris.data
data = pd.DataFrame(X)
std_slc = StandardScaler()
X_std = std_slc.fit_transform(X)
clt = DBSCAN()
model = clt.fit(X_std)
clusters = pd.DataFrame(model.fit_predict(X_std))
data["Cluster"] = clusters
fig = plt.figure(figsize=(10,10)); ax = fig.add_subplot(111)
scatter = ax.scatter(data[0],data[1], c=data["Cluster"],s=65)
ax.set_title("Clustering")
plt.colorbar(scatter)

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.stats.api as sms
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# %%
raw_data1 = pd.read_csv('ab_data.csv')
session_counts = raw_data1['user_id'].value_counts(ascending=False)
multi_users = session_counts[session_counts > 1].count()
users_to_drop = session_counts[session_counts > 1].index
raw_data1 = raw_data1[~raw_data1['user_id'].isin(users_to_drop)]

# %%
control_sample = raw_data1[raw_data1['group'] == 'control'].sample(n=4720, random_state=22)
treatment_sample = raw_data1[raw_data1['group'] == 'treatment'].sample(n=4720, random_state=22)
ab_test = pd.concat([control_sample, treatment_sample], axis=0)
ab_test.reset_index(drop=True, inplace=True)

# %%
conversion_rates = ab_test.groupby('group')['converted']
a = lambda x: np.std(x, ddof=0)
b = lambda x: stats.sem(x, ddof=0)            
conversion_rates = conversion_rates.agg([np.mean, a, b])
conversion_rates.columns = ['conversion_rate', 'deviation', 'error']
print(conversion_rates)
plt.figure(figsize=(8,6))
sns.barplot(x=ab_test['group'], y=ab_test['converted'], ci=False)
plt.title('Conversion rate by group', pad=20)
plt.xlabel('Group', labelpad=15)
plt.ylabel('Converted (proportion)', labelpad=15)
plt.show()
# Out:
#            conversion_rate  deviation     error
# group
# control           0.123305   0.328787  0.004786
# treatment         0.125636   0.331438  0.004824

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
columns = raw_data.columns
x = raw_data.loc[:, columns].values
y = raw_data.loc[:,['DEATH_EVENT']].values

# %%
x_std = StandardScaler().fit_transform(x)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
pca_raw_data = pd.DataFrame(data = principalComponents, columns = ['PCA One', 'PCA Two'])
final_pca_raw_data = pd.concat([pca_raw_data, raw_data[['DEATH_EVENT']]], axis = 1)
print(final_pca_raw_data)
# Out:
#            PCA One      PCA Two  DEATH_EVENT
# 0      1641.969405    -0.145884            1
# 1         1.766518  7279.254991            1
# 2   -101358.133290  -411.138633            1
# 3    -53358.143086  -457.772070            1
# 4     63641.865204  -437.190760            1
# ..             ...          ...          ...
# 294 -108358.151303  -494.646434            0
# 295    6642.272281  1236.444789            0
# 296  478642.316896  1361.875602            0
# 297 -123357.579804  1861.000145            0
# 298  131641.874613  -417.903341            0
#
# [299 rows x 3 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PCA One', fontsize = 15)
ax.set_ylabel('PCA Two', fontsize = 15)
ax.set_title('PCA Visualization', fontsize = 20)
targets = [0,1]
colors = ['yellow', 'green']
for target, color in zip(targets,colors):
    indicesToKeep = final_pca_raw_data['DEATH_EVENT'] == target
    ax.scatter(final_pca_raw_data.loc[indicesToKeep, 'PCA One'], final_pca_raw_data.loc[indicesToKeep, 'PCA Two'], c = color, s = 50)
ax.legend(targets)
ax.grid()
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.preprocessing import StandardScaler, normalize
import scipy.cluster.hierarchy as shc

# %%
normalized_data = normalize(scaled_data1)
normalized_data = pd.DataFrame(normalized_data)

# %%
Dendrogram = shc.dendrogram((shc.linkage(normalized_data, method ='ward')))
plt.show()
